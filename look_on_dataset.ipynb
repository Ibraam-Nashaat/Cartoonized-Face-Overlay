# %%
import numpy as np
import pandas as pd
from utils import Utils
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
utils = Utils()

# %%
#train_faces = utils.read_pgm_dataset('./dataset/train/face/')
test_faces = utils.read_pgm_dataset('./dataset/test/face/')
#train_non_faces = utils.read_pgm_dataset('./dataset/train/non-face/')
test_non_faces = utils.read_pgm_dataset('./dataset/test/non-face/')



utils.save_pickle(test_faces, './dataset/pkls/test/faces.pkl')
utils.save_pickle(test_non_faces, './dataset/pkls/test/non_faces.pkl')
#utils.save_pickle(test_faces, './dataset/pkls/train/faces.pkl')
#utils.save_pickle(test_non_faces, './dataset/pkls/train/non_faces.pkl')

# %%
train_faces = utils.load_pickle('./dataset/pkls/train/faces.pkl')
train_non_faces = utils.load_pickle('./dataset/pkls/train/non_faces.pkl')

# %%
n_train_faces = train_faces.shape[0]
n_train_non_faces = train_non_faces.shape[0]
n_test_faces = test_faces.shape[0]
n_test_non_faces = test_non_faces.shape[0]
print('n_train_faces: ', n_train_faces)
print('n_train_non_faces: ', n_train_non_faces)
print('n_test_faces: ', n_test_faces)
print('n_test_non_faces: ', n_test_non_faces)
# Out:
# n_train_faces:  2429
# n_train_non_faces:  4548
# n_test_faces:  472
# n_test_non_faces:  23573

# %%
utils.display_random_images(train_faces, 15)

# %%
utils.display_random_images(train_non_faces, 15)
